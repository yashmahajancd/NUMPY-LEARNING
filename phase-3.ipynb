# %% [markdown]
# # Advance operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data structure : [restaurant_id, 2021, 2022, 2023, 2024]

sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],   # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],   # Beijing Bites
    [3, 200000, 230000, 260000, 300000],   # Pizza Hub
    [4, 180000, 210000, 240000, 270000],   # Burger Point
    [5, 160000, 185000, 205000, 230000]    # Chai Point
])

print("==== Zomato sales analysis ====")
print(f"\nSales data shape : {sales_data.shape}")
print(f"\nFirst three restaurant :\n{sales_data[:3]}")
# print(f"\nFirst three restaurant :\n{sales_data[:, 1:]}")
# Out:
# ==== Zomato sales analysis ====
#
# Sales data shape : (5, 5)
#
# First three restaurant :
# [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# Total sales per year
print(np.sum(sales_data, axis=0))

yearly_total = np.sum(sales_data[:, 1:], axis=0)
print(yearly_total)
print(np.sum(yearly_total))


# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)
print(min_sales)

print("\n")
print("=" * 60)

# Maximum sales per year
max_sales_per_year = np.max(sales_data[:, 1:], axis=0)
print(f"\nMaximum sales per year : {max_sales_per_year}")

print(f"\nSales data :\n{sales_data[:, 1:]}")

total_sales_per_rest = np.sum(sales_data[:, 1:], axis=1)
print(f"\nTotal sales per restaurant : {total_sales_per_rest}")

max_sales = np.max(total_sales_per_rest)
print(f"Maximum sales : {max_sales}")

print("\n")
print("=" * 60)


# Average sales per restaurant
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print(f"\nAverage sales : {avg_sales}")
# Out:
# [     15  810000  945000 1085000 1240000]
# [ 810000  945000 1085000 1240000]
# 4080000
# [150000 120000 200000 180000 160000]
#
#
# ...
#
# Maximum sales per year : [200000 230000 260000 300000]
#
# Sales data :
# [[150000 180000 220000 250000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 205000 230000]]
#
# Total sales per restaurant : [800000 610000 990000 900000 780000]
# Maximum sales : 990000
#
#
# ...
#
# Average sales : [200000. 152500. 247500. 225000. 195000.]

# %% [markdown]
# ### Cumulative sales

# %%
# Cumulative sales
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(f"Cumulative sales :\n{cumsum}")


plt.figure(figsize=(8, 5))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumulative sales across all restaurant")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# Cumulative sales :
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %% [markdown]
# ## Vector operations

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

# Vector addition
print(f"Vector addition : {vector1 + vector2}")
print(f"\nMultiplication of vector : {vector1 * vector2}")

mutl_vector_sum = np.sum(vector1 * vector2)
print(f"Sum of Multiplication of vector : {mutl_vector_sum}")

# Dot product using dot()
print(f"\nDot product : {np.dot(vector1, vector2)}")

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(f"\nAngle : {angle}")
# Out:
# Vector addition : [ 7  9 11 13 15]
#
# Multiplication of vector : [ 6 14 24 36 50]
# Sum of Multiplication of vector : 130
#
# Dot product : 130
#
# Angle : 0.26554161733900966

# %% [markdown]
# ### Vectorized operation

# %%
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print(f"Vectorized upper : {vectorized_upper(restaurant_types)}")
# Out:
# Vectorized upper : ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %% [markdown]
# ### Broadcast

# %%
monthly_avg = sales_data[:, 1:] / 12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
